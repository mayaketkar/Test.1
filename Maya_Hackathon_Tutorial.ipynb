# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaketkar/Test.1/blob/main/Maya_Hackathon_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,197 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,632 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,494 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull llama3.2-vision
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏ 5.9 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   1% ▕▏  59 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   2% ▕▏ 110 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   2% ▕▏ 131 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   3% ▕▏ 167 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   3% ▕▏ 186 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   4% ▕▏ 213 MB/6.0 GB                  pulling manifest
# ...

# %%
# !pip3 install ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import ollama
import sys
import os
import time

def analyze_image(image_path, output_file=None):
    img = mpimg.imread(image_path)
    plt.figure(figsize=(10,10))
    plt.imshow(img)
    plt.show()

    response = ollama.chat(
        model='llama3.2-vision',
        messages=[{
            'role': 'user',
            'content': (
"""
Check the homework of the student and give them feedback.
How could the student do better?
"""
            ),
            'images': [image_path]
        }]
    )
    return(response)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
os.listdir("/content/drive/MyDrive/maya")
# Out:
# ['test1.jpeg']

# %%
result = analyze_image("/content/drive/MyDrive/maya/test1.jpeg")

# %%
from IPython.display import display, Markdown
display(Markdown(result.model_dump()["message"]["content"]))
# Out:
# **Student's Work**
#
# The student has attempted to solve a series of mathematical problems involving fractions and percentages.
#
# *   The first question asks the student to add 9/10 + 1/15
# *   The second question involves multiplying 2/5 x 3/4
# *   The third question requires adding 11/12 + 7/8
#
# **Analysis**
#
# The student's work shows some understanding of fraction addition and multiplication, but there are several errors throughout the solutions. For example:
#
# *   In the first question, the student incorrectly adds the fractions: 9/10 + 1/15 = (54+3)/60 = 57/60
# *   In the second question, the student fails to multiply the numerators and denominators correctly: 2/5 x 3/4 = (6/20) x (15/40)
# *   In the third question, the student incorrectly adds the fractions: 11/12 + 7/8 = (44+63)/96 = 107/96
#
# **Feedback**
#
# ...
