# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaketkar/Test.1/blob/main/Code_fest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Ollama

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [61.9 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,642 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,227 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,590 kB]
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull llama3.2-vision
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏    0 B/6.0 GB                  pulling manifest
# pulling 11f274007f09...   0% ▕▏ 5.9 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   1% ▕▏  52 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   2% ▕▏  97 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   2% ▕▏ 115 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   2% ▕▏ 142 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   3% ▕▏ 167 MB/6.0 GB                  pulling manifest
# pulling 11f274007f09...   3% ▕▏ 185 MB/6.0 GB                  pulling manifest
# ...

# %%
# !pip3 install ollama

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import ollama
import sys
import os
import time

def analyze_image(image_path, output_file=None):
    img = mpimg.imread(image_path)
    plt.figure(figsize=(10,10))
    plt.imshow(img)
    plt.show()

    response = ollama.chat(
        model='llama3.2-vision',
        messages=[{
            'role': 'user',
            'content': (
"""
Check the homework of the student and give them feedback.
"""
            ),
            'images': [image_path]
        }]
    )
    return(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-3744be51c65b> in <cell line: 4>()
#       2 import matplotlib.image as mpimg
#       3 import random
# ----> 4 import ollama
#       5 import sys
#       6 import os
#
# ModuleNotFoundError: No module named 'ollama'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
os.listdir("/content/drive/MyDrive/maya")
# Out:
# ['test1.jpeg', 'test2.jpeg', 'IMG_0456.JPG']

# %%
result = analyze_image("/content/drive/MyDrive/maya/test.jpeg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5533de0af985> in <cell line: 1>()
# ----> 1 result = analyze_image("/content/drive/MyDrive/maya/test.jpeg")
#
# NameError: name 'analyze_image' is not defined

# %%
from IPython.display import display, Markdown
display(Markdown('result''model_dump'()["message"]["content"]))
# Out:
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <ipython-input-5-9bb47f7004d1>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   display(Markdown('result''model_dump'()["message"]["content"]))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9bb47f7004d1> in <cell line: 2>()
#       1 from IPython.display import display, Markdown
# ----> 2 display(Markdown('result''model_dump'()["message"]["content"]))
#
# TypeError: 'str' object is not callable
